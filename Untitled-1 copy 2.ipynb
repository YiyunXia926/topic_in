# %%
import yfinance as yf
import pandas as pd
import numpy as np
from fredapi import Fred
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import glob
import scipy.optimize as sco
import torch
import torch.nn as nn
import torch.optim as optim
import time
import seaborn as sns
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# data

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import time


start_date = "2013-01-01"
end_date = "2023-12-31"


sp500_file_path = 'sp500_companies.csv'
sp500_df = pd.read_csv(sp500_file_path)
sp500_tickers = sp500_df['Symbol'].tolist()

sp500_tickers = [ticker.replace('.', '-') for ticker in sp500_tickers]


stocks = []
for ticker in sp500_tickers:
    try:
        
        for attempt in range(3):
            try:
                stock_data = yf.download(ticker, start=start_date, end=end_date, progress=False)
                if not stock_data.empty:
                    break
                else:
                    raise ValueError("Empty data received")
            except Exception as e:
                if attempt < 2:
                    print(f"Attempt {attempt + 1} failed for {ticker}. Retrying after delay...")
                    time.sleep(5)  
                else:
                    raise e

        
        if stock_data.empty or len(stock_data) < 1000:
            print(f"Failed to download sufficient data for {ticker}: Data is empty or insufficient ({len(stock_data)} records)\n")
            continue

        
        stock = yf.Ticker(ticker)
        financials = stock.info
        market_cap = financials.get('marketCap', np.nan)

        if not np.isnan(market_cap):
            stocks.append({
                'Ticker': ticker,
                'MarketCap': market_cap
            })
        else:
            print(f"Failed to retrieve market cap for {ticker}: Market cap is NaN\n")

    except KeyError as e:
        print(f"Failed to download data for {ticker}: KeyError - {e}\n")
    except Exception as e:
        print(f"Failed to process {ticker}: {e}\n")


stocks_df = pd.DataFrame(stocks)


top_stocks_df = stocks_df.dropna(subset=['MarketCap']).sort_values(by='MarketCap', ascending=False).head(20)
print("Top 20 Stocks by Market Capitalization：")
print(top_stocks_df)
plt.figure(figsize=(10, 6))
plt.bar(top_stocks_df['Ticker'], top_stocks_df['MarketCap'] / 1e9, color='purple')
plt.title("Top 20 Stocks by Market Capitalization", fontsize=16)
plt.xlabel("Ticker", fontsize=12)
plt.ylabel("Market Cap (Billion USD)", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Failed to download sufficient data for ABNB: Data is empty or insufficient (768 records)
# 1 Failed download:
# ['AMTM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Attempt 1 failed for AMTM. Retrying after delay...
# 1 Failed download:
# ['AMTM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Attempt 2 failed for AMTM. Retrying after delay...
# 1 Failed download:
# ['AMTM']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Failed to process AMTM: Empty data received
#
# Failed to download sufficient data for CARR: Data is empty or insufficient (953 records)
#
# Failed to download sufficient data for CEG: Data is empty or insufficient (490 records)
# 1 Failed download:
# ['GEV']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Failed to download sufficient data for GEHC: Data is empty or insufficient (261 records)
#
# Attempt 1 failed for GEV. Retrying after delay...
# 1 Failed download:
# ['GEV']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Attempt 2 failed for GEV. Retrying after delay...
# 1 Failed download:
# ['GEV']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Failed to process GEV: Empty data received
#
# Failed to download sufficient data for KVUE: Data is empty or insufficient (166 records)
# 1 Failed download:
# ['LYB']: ConnectionError(ReadTimeoutError("HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out."))
# Attempt 1 failed for LYB. Retrying after delay...
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/LYB?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=LYB&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for LYB: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MTB?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MTB&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MTB: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MRO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MRO&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MRO: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MPC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MPC&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MPC: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MKTX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MKTX&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MKTX: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAR&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MAR: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MMC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MMC&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MMC: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MLM?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MLM&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MLM: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAS&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MAS: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MA&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MA: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MTCH?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MTCH&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MTCH: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MKC?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MKC&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MKC: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MCD?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MCD&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MCD: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MCK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MCK&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MCK: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MDT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MDT&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MDT: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MRK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MRK&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MRK: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/META?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=META&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for META: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MET?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MET&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MET: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MTD?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MTD&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MTD: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MGM?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MGM&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MGM: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MCHP?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MCHP&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MCHP: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MU?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MU&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MU: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MSFT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MSFT&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MSFT: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MAA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MAA&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MAA: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MRNA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MRNA&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MRNA: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MHK?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MHK&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MHK: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MOH?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MOH&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MOH: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/TAP?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=TAP&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for TAP: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MDLZ?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MDLZ&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MDLZ: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MPWR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MPWR&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MPWR: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MNST?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MNST&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MNST: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MCO?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MCO&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MCO: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MS&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MS: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MOS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MOS&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MOS: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MSI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MSI&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MSI: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MSCI?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MSCI&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for MSCI: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NDAQ?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NDAQ&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for NDAQ: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTAP?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTAP&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for NTAP: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NFLX?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NFLX&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for NFLX: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NEM?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NEM&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for NEM: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NWSA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NWSA&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for NWSA: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NWS?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NWS&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for NWS: Market cap is NaN
# 401 Client Error: Unauthorized for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NEE?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NEE&crumb=FN6Lgif7RLK
# Failed to retrieve market cap for NEE: Market cap is NaN
#
# Failed to download sufficient data for OTIS: Data is empty or insufficient (953 records)
#
# Failed to download sufficient data for PLTR: Data is empty or insufficient (818 records)
# 1 Failed download:
# ['SW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Attempt 1 failed for SW. Retrying after delay...
# 1 Failed download:
# ['SW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Attempt 2 failed for SW. Retrying after delay...
# 1 Failed download:
# ['SW']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Failed to process SW: Empty data received
# 1 Failed download:
# ['SOLV']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Attempt 1 failed for SOLV. Retrying after delay...
# 1 Failed download:
# ['SOLV']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Attempt 2 failed for SOLV. Retrying after delay...
# 1 Failed download:
# ['SOLV']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2013-01-01 -> 2023-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1357016400, endDate = 1703998800")')
# Failed to process SOLV: Empty data received
#
# Failed to download sufficient data for VLTO: Data is empty or insufficient (61 records)
#
# Top 20 Stocks by Market Capitalization：
#     Ticker      MarketCap
# 37    AAPL  3553119698944
# 299   NVDA  3353170935808
# 21    AMZN  2185648013312
# 18   GOOGL  2078501634048
# 19    GOOG  2078492721152
# 390   TSLA  1085738647552
# 58   BRK-B  1032349548544
# 70    AVGO   769431437312
# 428    WMT   733972594688
# 282    LLY   709848072192
# 262    JPM   703750537216
# 421      V   603424751616
# 411    UNH   558419148800
# 308   ORCL   527526658048
# 183    XOM   518488752128
# 126   COST   430446379008
# 228     HD   426669277184
# 329     PG   422282231808
# 260    JNJ   372025458688
# 55     BAC   366380023808

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import time
import scipy.optimize as sco


# 市值前 20 的股票代码
portfolio_tickers = [
    "NVDA", "AAPL", "MSFT", "GOOGL", "GOOG", "AMZN", "META", "TSLA", "BRK-B", "AVGO", "LLY",
    "WMT", "JPM", "V", "UNH", "XOM", "ORCL", "MA", "COST", "PG"
]
# Download historical price data
start_date = "2013-01-01"
end_date = "2023-12-31"
data = yf.download(portfolio_tickers, start=start_date, end=end_date)['Adj Close']

# Clean the data: fill missing values and drop columns/rows with all NaNs
data = data.ffill().bfill().dropna(how='all', axis=1).dropna(how='all', axis=0)

# Filter out tickers with insufficient data (less than 1000 trading days)
sufficient_data_tickers = data.columns[data.notna().sum() > 1000]
filtered_data = data[sufficient_data_tickers]

# If there are not enough tickers, exit early
if len(sufficient_data_tickers) < 2:
    print("Not enough tickers with sufficient data for optimization.")
    exit()

# Calculate daily returns
returns = filtered_data.pct_change().dropna()

# Calculate mean and covariance of returns
mean_returns = returns.mean()
cov_matrix = returns.cov()

# Risk-free rate for Sharpe ratio calculation
risk_free_rate = 0.02

# Portfolio Performance Function
def portfolio_performance(weights, mean_returns, cov_matrix, risk_free_rate):
    returns = np.sum(mean_returns * weights) * 252
    risk = np.sqrt(np.dot(weights.T, np.dot(cov_matrix * 252, weights)))
    sharpe_ratio = (returns - risk_free_rate) / risk
    return returns, risk, sharpe_ratio

# Negative Sharpe Ratio Function for Optimization
def negative_sharpe_ratio(weights, mean_returns, cov_matrix, risk_free_rate):
    return -portfolio_performance(weights, mean_returns, cov_matrix, risk_free_rate)[2]

# Constraints and Bounds
constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
bounds = tuple((0, 1) for _ in range(len(sufficient_data_tickers)))

# Initial Weights
initial_weights = len(sufficient_data_tickers) * [1. / len(sufficient_data_tickers)]

# Optimization to Maximize Sharpe Ratio
optimal_result = sco.minimize(negative_sharpe_ratio, initial_weights, args=(mean_returns, cov_matrix, risk_free_rate),
                              method='SLSQP', bounds=bounds, constraints=constraints)

# Extract Optimal Weights
optimal_weights = optimal_result.x

# Filter out stocks with very small allocations (near 0%)
filtered_tickers = [ticker for ticker, weight in zip(sufficient_data_tickers, optimal_weights) if weight > 0.001]
filtered_weights = [weight for weight in optimal_weights if weight > 0.001]

# Output the Optimal Portfolio
opt_returns, opt_risk, opt_sharpe = portfolio_performance(optimal_weights, mean_returns, cov_matrix, risk_free_rate)

print("Expected annual return of the optimal portfolio: {:.2f}%".format(opt_returns * 100))
print("Expected annual volatility of the optimal portfolio: {:.2f}%".format(opt_risk * 100))
print("Optimal Sharpe ratio: {:.2f}".format(opt_sharpe))
print("Optimal weight allocation:")
for ticker, weight in zip(filtered_tickers, filtered_weights):
    print(f"{ticker}: {weight:.2%}")

# Visualize Optimal Portfolio Weight Allocation with an exploded view to prevent overlap
plt.figure(figsize=(12, 8))
plt.pie(filtered_weights, labels=filtered_tickers, autopct='%1.1f%%', startangle=140,
        wedgeprops={'linewidth': 1, 'edgecolor': 'black'}, pctdistance=0.85, labeldistance=1.1)
plt.title('Optimal Portfolio Weight Allocation')
plt.tight_layout()
plt.show()
# Out:
# [*********************100%***********************]  20 of 20 completed
# Expected annual return of the optimal portfolio: 37.28%
# Expected annual volatility of the optimal portfolio: 22.11%
# Optimal Sharpe ratio: 1.60
# Optimal weight allocation:
# AVGO: 12.79%
# COST: 12.84%
# LLY: 31.78%
# NVDA: 18.02%
# TSLA: 11.92%
# UNH: 12.65%

# %%
import tensorflow as tf

if tf.config.list_physical_devices('GPU'):
    print("Using GPU")
else:
    print("Using CPU")
# Out:
# Using CPU

# %%
import yfinance as yf
import pandas as pd

# Download historical data for the portfolio tickers again (corrected to 'UNH')
portfolio_tickers = ['AVGO', 'COST', 'LLY', 'NVDA', 'TSLA', 'UNH']
start_date = '2013-01-01'
end_date = '2024-11-20'

# Download the data from Yahoo Finance
data = yf.download(portfolio_tickers, start=start_date, end=end_date)['Adj Close']
data = data.fillna(method='ffill').fillna(method='bfill')

# Load the data to investigate UNH
unh_data = data['UNH']

# Check if there are any missing values and the overall summary of the data
unh_summary = unh_data.describe()
unh_missing_values = unh_data.isna().sum()

# Identify periods of zero or near-zero variation in the price data
unh_constant_periods = (unh_data.diff().abs() < 1e-5).sum()

print("Summary of UNH data:", unh_summary)
print("Missing values in UNH data:", unh_missing_values)
print("Number of periods with near-zero variation in UNH data:", unh_constant_periods)
# Out:
# [*********************100%***********************]  6 of 6 completed
# Summary of UNH data: count    2992.000000
# mean      259.907365
# std       165.935963
# min        42.915771
# 25%       105.056721
# 50%       226.376869
# 75%       438.254066
# max       625.250000
# Name: UNH, dtype: float64
# Missing values in UNH data: 0
# Number of periods with near-zero variation in UNH data: 8
# C:\Users\a1669\AppData\Local\Temp\ipykernel_20840\513738570.py:11: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method='ffill').fillna(method='bfill')

# %%
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, Input
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.optimizers import Adam
from keras.models import Model
import scipy.optimize as sco
import datetime

portfolio_tickers = [
    'AVGO', 'COST', 'LLY', 'NVDA', 'TSLA', 'UNH'  # Corrected from 'UHN' to 'UNH'
]

# Data fetching
start_date = '2013-01-01'
end_date = '2024-11-20'

# Download historical data
data = yf.download(portfolio_tickers, start=start_date, end=end_date)['Adj Close']
data = data.ffill().bfill()  # Updated deprecated method call

# Initialize lists to hold predictions for each stock
future_predictions_list = []

# Iterate over each stock for individual analysis and prediction
for ticker in portfolio_tickers:
    # Extract the price data for the current stock
    stock_prices = data[ticker]

    # Split data into training and test sets
    train_size = int(len(stock_prices) * 0.8)
    train_stock, test_stock = stock_prices[:train_size], stock_prices[train_size:]

    # Scale data
    scaler_stock = MinMaxScaler(feature_range=(0, 1))
    train_stock_scaled = scaler_stock.fit_transform(train_stock.values.reshape(-1, 1))

    # Convert to LSTM format
    def create_lstm_dataset(dataset, look_back=50):
        X, y = [], []
        for i in range(look_back, len(dataset)):
            X.append(dataset[i-look_back:i, 0])
            y.append(dataset[i, 0])
        return np.array(X), np.array(y)

    X_train_stock, y_train_stock = create_lstm_dataset(train_stock_scaled)

    # Reshape input to be [samples, time steps, features]
    X_train_stock = X_train_stock.reshape((X_train_stock.shape[0], X_train_stock.shape[1], 1))

    # Create LSTM model
    def create_lstm_model(input_shape):
        inputs = Input(shape=input_shape)
        x = LSTM(128, return_sequences=True)(inputs)  # Reduced units to speed up training
        x = Dropout(0.2)(x)  # Reduced dropout rate to speed up training
        x = LSTM(128)(x)
        x = Dropout(0.2)(x)
        output = Dense(1)(x)
        model = Model(inputs, output)
        model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')
        return model

    # Reduce learning rate on plateau and add early stopping
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=0.0001)  # Reduced patience to speed up training
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)  # Reduced patience to speed up training

    # Train LSTM model for the stock
    lstm_model_stock = create_lstm_model((X_train_stock.shape[1], 1))
    lstm_model_stock.fit(X_train_stock, y_train_stock, epochs=50, batch_size=32, verbose=1, validation_split=0.2, callbacks=[reduce_lr, early_stopping])  # Reduced epochs and batch size to speed up training

    # Make predictions for the test set
    if len(test_stock) > 50:
        test_stock_scaled = scaler_stock.transform(test_stock.values.reshape(-1, 1))
        X_test_stock, y_test_stock = create_lstm_dataset(test_stock_scaled)
        X_test_stock = X_test_stock.reshape((X_test_stock.shape[0], X_test_stock.shape[1], 1))
        
        # Predict and inverse transform
        y_pred_scaled = lstm_model_stock.predict(X_test_stock)
        y_pred = scaler_stock.inverse_transform(y_pred_scaled)
        y_test = scaler_stock.inverse_transform(y_test_stock.reshape(-1, 1))

        # Calculate evaluation metrics
        mse = mean_squared_error(y_test, y_pred)
        mae = mean_absolute_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)

        print(f"Evaluation for {ticker} - MSE: {mse}, MAE: {mae}, R^2: {r2}")

        # Visualize predictions vs actual prices
        plt.figure(figsize=(10, 6))
        plt.plot(y_test, label='Actual Prices')
        plt.plot(y_pred, label='Predicted Prices')
        plt.title(f'{ticker} - Actual vs Predicted Prices')
        plt.xlabel('Days')
        plt.ylabel('Price')
        plt.legend()
        plt.show()

        # If metrics are satisfactory, proceed with future predictions
        if mse < 1e4 and mae < 50 and r2 > 0.7:
            future_steps = 252  # Assume 252 trading days in a year
            last_train_scaled = train_stock_scaled[-50:]
            future_predictions = []
            current_input = last_train_scaled

            for _ in range(future_steps):
                current_input = current_input.reshape((1, current_input.shape[0], 1))
                next_prediction = lstm_model_stock.predict(current_input)
                future_predictions.append(next_prediction[0, 0])
                current_input = np.append(current_input[0, 1:, 0], next_prediction[0, 0]).reshape(-1, 1)

            future_predictions = scaler_stock.inverse_transform(np.array(future_predictions).reshape(-1, 1))
            future_predictions_list.append(future_predictions)

# Calculate Expected Returns Based on Predictions
expected_returns = []
valid_tickers = []

for i, ticker in enumerate(portfolio_tickers):
    if i < len(future_predictions_list):  # Check to avoid index out of range error
        # Calculate expected annualized return based on predicted future prices
        predicted_prices = future_predictions_list[i]
        daily_returns = (predicted_prices[1:] - predicted_prices[:-1]) / predicted_prices[:-1]
        expected_annual_return = np.mean(daily_returns) * 252  # Assuming 252 trading days
        expected_returns.append(expected_annual_return)
        valid_tickers.append(ticker)  # Keep track of tickers with valid predictions

expected_returns = np.array(expected_returns)
print(f"Expected Returns for each stock: {expected_returns}")

# Align provided weights with valid tickers
provided_weights = [0.1279, 0.1284, 0.3178, 0.1802, 0.1192, 0.1265][:len(valid_tickers)]

# Portfolio optimization with expected returns
historical_returns = data[valid_tickers].pct_change().mean() * 252
cov_matrix = data[valid_tickers].pct_change().cov() * 252

# Objective function to minimize (negative Sharpe Ratio)
def negative_sharpe(weights, returns, cov_matrix, risk_free_rate=0.01):
    portfolio_return = np.dot(weights, returns)
    portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    sharpe_ratio = (portfolio_return - risk_free_rate) / portfolio_volatility
    return -sharpe_ratio

# Constraints and bounds
constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
bounds = tuple((0.05, 0.4) for _ in range(len(valid_tickers)))  # Enforcing diversification by adding minimum and maximum weight constraints
initial_weights = provided_weights[:len(valid_tickers)]

# Calculate metrics for provided weights
provided_portfolio_return = np.dot(provided_weights, expected_returns)
provided_portfolio_volatility = np.sqrt(np.dot(provided_weights, np.dot(cov_matrix, provided_weights)))
provided_sharpe_ratio = (provided_portfolio_return - 0.01) / provided_portfolio_volatility

print(f"Provided Portfolio - Expected Return: {provided_portfolio_return:.4f}, Volatility: {provided_portfolio_volatility:.4f}, Sharpe Ratio: {provided_sharpe_ratio:.4f}")

# Optimize portfolio using expected returns
if len(expected_returns) == len(valid_tickers):  # Ensure expected returns are available for all tickers
    optimized_results = sco.minimize(negative_sharpe, initial_weights, args=(expected_returns, cov_matrix), method='SLSQP', bounds=bounds, constraints=constraints)
    if optimized_results.success:
        optimized_weights = optimized_results.x

        # Calculate metrics for optimized portfolio
        optimized_portfolio_return = np.dot(optimized_weights, expected_returns)
        optimized_portfolio_volatility = np.sqrt(np.dot(optimized_weights.T, np.dot(cov_matrix, optimized_weights)))
        optimized_sharpe_ratio = (optimized_portfolio_return - 0.01) / optimized_portfolio_volatility

        print(f"Optimized Portfolio - Expected Return: {optimized_portfolio_return:.4f}, Volatility: {optimized_portfolio_volatility:.4f}, Sharpe Ratio: {optimized_sharpe_ratio:.4f}")

        # Visualize Optimal Portfolio Weight Allocation
        plt.figure(figsize=(12, 8))
        wedges, texts, autotexts = plt.pie(optimized_weights, labels=valid_tickers, autopct='%1.1f%%', startangle=140,
                                           wedgeprops={'linewidth': 1, 'edgecolor': 'black'}, pctdistance=0.85, labeldistance=1.1)
        plt.setp(autotexts, size=10, weight='bold')
        plt.setp(texts, size=12)
        plt.title('Optimal Portfolio Weight Allocation (Based on Predicted Returns)')
        plt.tight_layout()
        plt.show()

        # Print optimized weights
        for ticker, weight in zip(valid_tickers, optimized_weights):
            print(f'{ticker}: {weight:.4f}')
    else:
        print("Optimization failed. No valid solution found.")
else:
    print("Expected returns not available for all tickers. Skipping optimization.")
# Out:
# [*********************100%***********************]  6 of 6 completed
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0093 - val_loss: 0.0031 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.4913e-04 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.8971e-04 - val_loss: 9.9630e-04 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5263e-04 - val_loss: 8.0386e-04 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.4651e-04 - val_loss: 7.8299e-04 - learning_rate: 0.0010
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7948e-04 - val_loss: 7.5835e-04 - learning_rate: 0.0010
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.9710e-04 - val_loss: 9.5786e-04 - learning_rate: 0.0010
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.3719e-04 - val_loss: 0.0021 - learning_rate: 5.0000e-04
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1052e-04 - val_loss: 9.7588e-04 - learning_rate: 5.0000e-04
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.6746e-04 - val_loss: 0.0012 - learning_rate: 5.0000e-04
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.5092e-04 - val_loss: 0.0015 - learning_rate: 2.5000e-04
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.6898e-04 - val_loss: 8.2612e-04 - learning_rate: 2.5000e-04
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.8623e-04 - val_loss: 9.2205e-04 - learning_rate: 2.5000e-04
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4363e-04 - val_loss: 0.0013 - learning_rate: 1.2500e-04
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.5108e-04 - val_loss: 7.8511e-04 - learning_rate: 1.2500e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.8151e-04 - val_loss: 0.0010 - learning_rate: 1.2500e-04
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Evaluation for AVGO - MSE: 221.82622352796216, MAE: 10.120657026224883, R^2: 0.8770026091011329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 0.0059 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4820e-04 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4235e-04 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.3811e-04 - val_loss: 0.0016 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0164e-04 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0099e-04 - val_loss: 8.6701e-04 - learning_rate: 5.0000e-04
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1539e-04 - val_loss: 0.0011 - learning_rate: 5.0000e-04
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8793e-04 - val_loss: 9.6441e-04 - learning_rate: 5.0000e-04
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8147e-04 - val_loss: 0.0012 - learning_rate: 5.0000e-04
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.0243e-04 - val_loss: 0.0011 - learning_rate: 2.5000e-04
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8363e-04 - val_loss: 8.6892e-04 - learning_rate: 2.5000e-04
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7697e-04 - val_loss: 9.1528e-04 - learning_rate: 2.5000e-04
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7726e-04 - val_loss: 8.9826e-04 - learning_rate: 1.2500e-04
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7788e-04 - val_loss: 8.6433e-04 - learning_rate: 1.2500e-04
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8932e-04 - val_loss: 7.7745e-04 - learning_rate: 1.2500e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8819e-04 - val_loss: 8.0773e-04 - learning_rate: 1.0000e-04
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5465e-04 - val_loss: 8.1392e-04 - learning_rate: 1.0000e-04
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7913e-04 - val_loss: 8.0356e-04 - learning_rate: 1.0000e-04
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7204e-04 - val_loss: 0.0012 - learning_rate: 1.0000e-04
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7595e-04 - val_loss: 8.1700e-04 - learning_rate: 1.0000e-04
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3120e-04 - val_loss: 7.9417e-04 - learning_rate: 1.0000e-04
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6337e-04 - val_loss: 7.5820e-04 - learning_rate: 1.0000e-04
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5869e-04 - val_loss: 7.4224e-04 - learning_rate: 1.0000e-04
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4791e-04 - val_loss: 9.0770e-04 - learning_rate: 1.0000e-04
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6224e-04 - val_loss: 7.6400e-04 - learning_rate: 1.0000e-04
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6538e-04 - val_loss: 7.2946e-04 - learning_rate: 1.0000e-04
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7001e-04 - val_loss: 7.2729e-04 - learning_rate: 1.0000e-04
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7509e-04 - val_loss: 7.2846e-04 - learning_rate: 1.0000e-04
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4384e-04 - val_loss: 7.2155e-04 - learning_rate: 1.0000e-04
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.5110e-04 - val_loss: 0.0010 - learning_rate: 1.0000e-04
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5038e-04 - val_loss: 7.4085e-04 - learning_rate: 1.0000e-04
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2509e-04 - val_loss: 7.5062e-04 - learning_rate: 1.0000e-04
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3891e-04 - val_loss: 7.0300e-04 - learning_rate: 1.0000e-04
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4296e-04 - val_loss: 8.0389e-04 - learning_rate: 1.0000e-04
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5363e-04 - val_loss: 7.0691e-04 - learning_rate: 1.0000e-04
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4011e-04 - val_loss: 6.9269e-04 - learning_rate: 1.0000e-04
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3390e-04 - val_loss: 0.0012 - learning_rate: 1.0000e-04
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3577e-04 - val_loss: 6.9904e-04 - learning_rate: 1.0000e-04
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4840e-04 - val_loss: 9.8689e-04 - learning_rate: 1.0000e-04
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5654e-04 - val_loss: 7.4354e-04 - learning_rate: 1.0000e-04
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7241e-04 - val_loss: 7.1565e-04 - learning_rate: 1.0000e-04
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3930e-04 - val_loss: 7.1766e-04 - learning_rate: 1.0000e-04
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.4891e-04 - val_loss: 7.8399e-04 - learning_rate: 1.0000e-04
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.3332e-04 - val_loss: 6.6412e-04 - learning_rate: 1.0000e-04
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.3779e-04 - val_loss: 6.8375e-04 - learning_rate: 1.0000e-04
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.5250e-04 - val_loss: 6.6329e-04 - learning_rate: 1.0000e-04
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4115e-04 - val_loss: 9.2881e-04 - learning_rate: 1.0000e-04
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7581e-04 - val_loss: 6.6374e-04 - learning_rate: 1.0000e-04
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4225e-04 - val_loss: 7.0809e-04 - learning_rate: 1.0000e-04
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4258e-04 - val_loss: 6.9454e-04 - learning_rate: 1.0000e-04
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Evaluation for COST - MSE: 447.6487867640084, MAE: 16.27124512608151, R^2: 0.9821642864136115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0063 - val_loss: 0.0018 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1430e-04 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4800e-04 - val_loss: 0.0021 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.0369e-04 - val_loss: 0.0010 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1385e-04 - val_loss: 0.0011 - learning_rate: 0.0010
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5748e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8057e-04 - val_loss: 9.5000e-04 - learning_rate: 0.0010
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8054e-04 - val_loss: 0.0020 - learning_rate: 5.0000e-04
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4946e-04 - val_loss: 0.0019 - learning_rate: 5.0000e-04
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7039e-04 - val_loss: 9.6721e-04 - learning_rate: 5.0000e-04
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4873e-04 - val_loss: 0.0010 - learning_rate: 2.5000e-04
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4953e-04 - val_loss: 8.8638e-04 - learning_rate: 2.5000e-04
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3575e-04 - val_loss: 0.0014 - learning_rate: 2.5000e-04
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3458e-04 - val_loss: 0.0012 - learning_rate: 2.5000e-04
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3600e-04 - val_loss: 0.0018 - learning_rate: 2.5000e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3420e-04 - val_loss: 0.0010 - learning_rate: 1.2500e-04
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3762e-04 - val_loss: 0.0018 - learning_rate: 1.2500e-04
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3594e-04 - val_loss: 9.3784e-04 - learning_rate: 1.2500e-04
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2129e-04 - val_loss: 0.0010 - learning_rate: 1.0000e-04
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4688e-04 - val_loss: 0.0010 - learning_rate: 1.0000e-04
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2952e-04 - val_loss: 0.0011 - learning_rate: 1.0000e-04
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2461e-04 - val_loss: 9.3878e-04 - learning_rate: 1.0000e-04
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Evaluation for LLY - MSE: 6476.6781370567805, MAE: 59.38774934362193, R^2: 0.8535376888958431
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0014 - val_loss: 0.0024 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0612e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0721e-04 - val_loss: 0.0026 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3463e-04 - val_loss: 0.0017 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.5356e-05 - val_loss: 0.0075 - learning_rate: 0.0010
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.6760e-05 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.4249e-05 - val_loss: 0.0037 - learning_rate: 0.0010
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.8962e-05 - val_loss: 0.0017 - learning_rate: 5.0000e-04
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.8585e-05 - val_loss: 0.0016 - learning_rate: 5.0000e-04
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.8713e-05 - val_loss: 0.0024 - learning_rate: 5.0000e-04
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.2083e-05 - val_loss: 0.0017 - learning_rate: 2.5000e-04
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.2904e-05 - val_loss: 0.0015 - learning_rate: 2.5000e-04
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.4199e-05 - val_loss: 0.0024 - learning_rate: 2.5000e-04
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.7760e-05 - val_loss: 0.0019 - learning_rate: 2.5000e-04
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.4066e-05 - val_loss: 0.0018 - learning_rate: 2.5000e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.2528e-05 - val_loss: 0.0019 - learning_rate: 1.2500e-04
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.9912e-05 - val_loss: 0.0017 - learning_rate: 1.2500e-04
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.7896e-05 - val_loss: 0.0018 - learning_rate: 1.2500e-04
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.9283e-05 - val_loss: 0.0023 - learning_rate: 1.0000e-04
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.0905e-05 - val_loss: 0.0022 - learning_rate: 1.0000e-04
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.5308e-05 - val_loss: 0.0017 - learning_rate: 1.0000e-04
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.7951e-05 - val_loss: 0.0016 - learning_rate: 1.0000e-04
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Evaluation for NVDA - MSE: 20.363543055806, MAE: 3.0072851007319104, R^2: 0.987716332277091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 7.3695e-04 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.9185e-05 - val_loss: 0.0056 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.6002e-05 - val_loss: 0.0042 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0426e-04 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.5447e-05 - val_loss: 0.0021 - learning_rate: 5.0000e-04
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.7971e-05 - val_loss: 0.0032 - learning_rate: 5.0000e-04
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.8609e-05 - val_loss: 0.0075 - learning_rate: 5.0000e-04
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.9208e-05 - val_loss: 0.0098 - learning_rate: 5.0000e-04
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.3123e-05 - val_loss: 0.0052 - learning_rate: 2.5000e-04
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.8097e-05 - val_loss: 0.0043 - learning_rate: 2.5000e-04
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5516e-05 - val_loss: 0.0053 - learning_rate: 2.5000e-04
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.4722e-05 - val_loss: 0.0085 - learning_rate: 1.2500e-04
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.3798e-05 - val_loss: 0.0056 - learning_rate: 1.2500e-04
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5168e-05 - val_loss: 0.0064 - learning_rate: 1.2500e-04
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6190e-05 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Evaluation for TSLA - MSE: 231.5460677286329, MAE: 11.572603527965441, R^2: 0.8676144211110663
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0112 - val_loss: 0.0033 - learning_rate: 0.0010
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.1587e-04 - val_loss: 0.0013 - learning_rate: 0.0010
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.8648e-04 - val_loss: 0.0015 - learning_rate: 0.0010
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.7353e-04 - val_loss: 8.4660e-04 - learning_rate: 0.0010
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.4852e-04 - val_loss: 0.0023 - learning_rate: 0.0010
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.2511e-04 - val_loss: 0.0019 - learning_rate: 0.0010
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6491e-04 - val_loss: 0.0034 - learning_rate: 0.0010
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5737e-04 - val_loss: 5.9984e-04 - learning_rate: 5.0000e-04
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.9766e-04 - val_loss: 0.0025 - learning_rate: 5.0000e-04
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5853e-04 - val_loss: 9.4331e-04 - learning_rate: 5.0000e-04
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.2281e-04 - val_loss: 6.9451e-04 - learning_rate: 5.0000e-04
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7222e-04 - val_loss: 9.5905e-04 - learning_rate: 2.5000e-04
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5253e-04 - val_loss: 7.2896e-04 - learning_rate: 2.5000e-04
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.3549e-04 - val_loss: 7.4657e-04 - learning_rate: 2.5000e-04
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.0490e-04 - val_loss: 9.8372e-04 - learning_rate: 1.2500e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7471e-04 - val_loss: 0.0013 - learning_rate: 1.2500e-04
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.3006e-04 - val_loss: 6.0533e-04 - learning_rate: 1.2500e-04
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7050e-04 - val_loss: 5.6684e-04 - learning_rate: 1.0000e-04
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0711e-04 - val_loss: 8.8405e-04 - learning_rate: 1.0000e-04
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.8289e-04 - val_loss: 0.0011 - learning_rate: 1.0000e-04
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.0045e-04 - val_loss: 5.6332e-04 - learning_rate: 1.0000e-04
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.7326e-04 - val_loss: 8.3530e-04 - learning_rate: 1.0000e-04
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.9067e-04 - val_loss: 7.5585e-04 - learning_rate: 1.0000e-04
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.9763e-04 - val_loss: 6.2321e-04 - learning_rate: 1.0000e-04
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0459e-04 - val_loss: 8.3816e-04 - learning_rate: 1.0000e-04
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.8782e-04 - val_loss: 7.5091e-04 - learning_rate: 1.0000e-04
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.5484e-04 - val_loss: 5.9691e-04 - learning_rate: 1.0000e-04
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9458e-04 - val_loss: 5.2546e-04 - learning_rate: 1.0000e-04
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7323e-04 - val_loss: 0.0013 - learning_rate: 1.0000e-04
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5207e-04 - val_loss: 0.0013 - learning_rate: 1.0000e-04
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5665e-04 - val_loss: 0.0010 - learning_rate: 1.0000e-04
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1421e-04 - val_loss: 5.2471e-04 - learning_rate: 1.0000e-04
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5513e-04 - val_loss: 0.0011 - learning_rate: 1.0000e-04
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.0699e-04 - val_loss: 6.8535e-04 - learning_rate: 1.0000e-04
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9272e-04 - val_loss: 8.5356e-04 - learning_rate: 1.0000e-04
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.8636e-04 - val_loss: 8.6154e-04 - learning_rate: 1.0000e-04
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7374e-04 - val_loss: 0.0011 - learning_rate: 1.0000e-04
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.2226e-04 - val_loss: 8.3783e-04 - learning_rate: 1.0000e-04
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.8240e-04 - val_loss: 7.6985e-04 - learning_rate: 1.0000e-04
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0551e-04 - val_loss: 6.1000e-04 - learning_rate: 1.0000e-04
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0027e-04 - val_loss: 0.0011 - learning_rate: 1.0000e-04
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.1730e-04 - val_loss: 6.8953e-04 - learning_rate: 1.0000e-04
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# Evaluation for UNH - MSE: 237.6376195686712, MAE: 11.97604014356714, R^2: 0.8384041105282423
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Expected Returns for each stock: [ 0.14538856 -0.0022116   0.46561981 -0.08674075 -0.19881718]
# Provided Portfolio - Expected Return: 0.1270, Volatility: 0.2077, Sharpe Ratio: 0.5631
# Optimized Portfolio - Expected Return: 0.2132, Volatility: 0.2121, Sharpe Ratio: 0.9581
# AVGO: 0.2869
# COST: 0.2131
# LLY: 0.4000
# NVDA: 0.0500
# TSLA: 0.0500

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided Portfolio Metrics
provided_portfolio_return = 0.1024  # Replace with the actual value from the output
provided_portfolio_volatility = 0.1804  # Replace with the actual value from the output
provided_sharpe_ratio = 0.5132  # Replace with the actual value from the output

# Optimized Portfolio Metrics
optimized_portfolio_return = 0.1342  # Replace with the actual value from the output
optimized_portfolio_volatility = 0.1543  # Replace with the actual value from the output
optimized_sharpe_ratio = 0.8032  # Replace with the actual value from the output

# Create a bar chart to visualize portfolio metrics
labels = ['Return', 'Volatility', 'Sharpe Ratio']
provided_metrics = [provided_portfolio_return, provided_portfolio_volatility, provided_sharpe_ratio]
optimized_metrics = [optimized_portfolio_return, optimized_portfolio_volatility, optimized_sharpe_ratio]

x = np.arange(len(labels))  # label locations
width = 0.35  # width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, provided_metrics, width, label='Provided Portfolio')
rects2 = ax.bar(x + width/2, optimized_metrics, width, label='Optimized Portfolio')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Values')
ax.set_title('Comparison of Provided vs. Optimized Portfolio Metrics')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Attach a text label above each bar, displaying its height.
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Define the portfolio weights
weights = {
    'AVGO': 0.2869,
    'COST': 0.2131,
    'LLY': 0.4000,
    'NVDA': 0.0500,
    'TSLA': 0.0500
}

# Forecast future price data (2024)
# Note: Assuming future_predictions is defined elsewhere as a numpy array or list
future_predictions = np.random.rand(300) * 500  # Example data
future_prices = pd.DataFrame(future_predictions, columns=['Predicted Price'])

# Smooth the predicted price using exponential moving average
future_prices['Smoothed Price'] = future_prices['Predicted Price'].ewm(span=30, adjust=False).mean()

# Calculate simple moving averages (SMAs) over multiple time windows
future_prices['SMA_15'] = future_prices['Smoothed Price'].rolling(window=15).mean()
future_prices['SMA_30'] = future_prices['Smoothed Price'].rolling(window=30).mean()
future_prices['SMA_60'] = future_prices['Smoothed Price'].rolling(window=60).mean()
future_prices['SMA_100'] = future_prices['Smoothed Price'].rolling(window=100).mean()

# Drop rows with NaN values to avoid issues with moving average calculations
future_prices.dropna(subset=['SMA_15', 'SMA_60', 'SMA_30', 'SMA_100'], inplace=True)

# Find the point of golden cross: where the short-term SMA crosses the long-term SMA.
future_prices['Golden Cross_15_60'] = (future_prices['SMA_15'] > future_prices['SMA_60']) & (future_prices['SMA_15'].shift(1) <= future_prices['SMA_60'].shift(1))
future_prices['Golden Cross_30_100'] = (future_prices['SMA_30'] > future_prices['SMA_100']) & (future_prices['SMA_30'].shift(1) <= future_prices['SMA_100'].shift(1))

# Use the MACD indicator to determine buy and sell signals
short_window = 20
long_window = 50
signal_window = 9

future_prices['EMA_20'] = future_prices['Smoothed Price'].ewm(span=short_window, adjust=False).mean()
future_prices['EMA_50'] = future_prices['Smoothed Price'].ewm(span=long_window, adjust=False).mean()
future_prices['MACD'] = future_prices['EMA_20'] - future_prices['EMA_50']
future_prices['Signal Line'] = future_prices['MACD'].ewm(span=signal_window, adjust=False).mean()

# Find buy points where the MACD crosses the signal line and sell points where it crosses the signal line.
future_prices['Buy Signal'] = (future_prices['MACD'] > future_prices['Signal Line']) & (future_prices['MACD'].shift(1) <= future_prices['Signal Line'].shift(1))
future_prices['Sell Signal'] = (future_prices['MACD'] < future_prices['Signal Line']) & (future_prices['MACD'].shift(1) >= future_prices['Signal Line'].shift(1))

buy_signals = future_prices[future_prices['Buy Signal']]
sell_signals = future_prices[future_prices['Sell Signal']]

# Output date and price information for buy and sell signals
print("\nMACD signal for buy (2024):")
print(buy_signals[['Smoothed Price', 'MACD', 'Signal Line']])

print("\nMACD signal for sell (2024):")
print(sell_signals[['Smoothed Price', 'MACD', 'Signal Line']])

# Visualization of smoothed forecast prices and buy/sell signals for 2024
plt.figure(figsize=(14, 7))

# Plotting Smoothed Price instead of Predicted Price
plt.plot(future_prices['Smoothed Price'], label='Smoothed Price', color='blue')

# Using secondary y-axis for MACD and Signal Line
ax1 = plt.gca()
ax2 = ax1.twinx()
ax2.plot(future_prices['MACD'], label='MACD', color='purple', linestyle='--')
ax2.plot(future_prices['Signal Line'], label='Signal Line', color='orange', linestyle=':')

# Plotting buy and sell signals on primary axis
ax1.scatter(buy_signals.index, buy_signals['Smoothed Price'], label='Buy Signal', color='green', marker='^', s=100)
ax1.scatter(sell_signals.index, sell_signals['Smoothed Price'], label='Sell Signal', color='red', marker='v', s=100)

# Adding titles and labels
plt.title('Smoothed Predicted Portfolio Prices for 2024 with MACD Buy and Sell Signals')
ax1.set_xlabel('Time')
ax1.set_ylabel('Price')
ax2.set_ylabel('MACD / Signal Line')

# Adding legends for both axes
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
# Out:
# MACD signal for buy (2024):
#      Smoothed Price       MACD  Signal Line
# 100      289.304851   0.503379     0.100676
# 110      295.202877  -0.241700    -0.816465
# 143      257.018784  -9.612799    -9.665063
# 171      266.467431  -6.029690    -6.565304
# 228      251.814934 -14.426273   -14.973253
# 237      237.537788 -13.392390   -13.482255
# 271      252.849487  -4.669228    -5.049595
# 293      278.691297   4.026614     3.811002
#
# MACD signal for sell (2024):
#      Smoothed Price       MACD  Signal Line
# 103      272.871339   0.163816     0.319030
# 120      271.045607   0.856318     1.269771
# 158      241.994510  -2.743548    -2.291648
# 195      306.934347  19.256158    19.328710
# 235      232.459186 -13.525419   -13.471660
# 262      237.806585  -2.477631    -2.224461
# 288      249.371593   4.454058     4.861911
# 295      248.729480   3.160341     3.720421
